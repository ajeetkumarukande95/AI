# %%
# Set:Unorderd, Mutable, Duplicates are not allowed
#     We can only add immutable items

# Mutable: list, set , dict
# Immutable: int, float, tuple, bool, str

# Enclosed by {}string : Ordered, Immutable, Duplicates are allowed
# List : Ordered , Mutable, Duplicates are allowed
# Tuple: Ordered, Immuatble, Duplicates are allowed
# Set : Unorderd, Mutable, Duplicates are not allowed

str =' '
list= []
tuple=()
set= set()
dict={}


# Creating a set
fruits = {"apple", "banana", "cherry"}
print(fruits)  # Output: {'apple', 'banana', 'cherry'}

# Using set() function
numbers = set([1, 2, 3, 4, 5])
print(numbers)  # Output: {1, 2, 3, 4, 5}

a={}
type(a)

# duplicated not allowed in sets
s1 = {2,3,4,5,4,5,6,3,7}
print(s1) # duplicates are not allowed
type(s1)

# set are also not subscriptable bcoz not  ordered one
s1[0]   # error

s1[:3]


# We can only add immutable items
set1= {1,2.2,3+4j,'a',[2,3,4]}
set1------# error unhshable

set1= {1,2.2,3+4j,'a',(2,3,4)}
set1

set1= {1,2.2,3+4j,'a',{'a':1,'b':3}}
set1

# set from tuple
t1 =(2,3,4,5)
s1=set(t1)
s1

# set friom list not possible(mutable)
t1 =[2,3,4,5]
s1=set(t1)
s1

# How to access set items
set1 ={2,3,'python', 'data', 'science', 4,600,6,7}
print(set1)

for i in set1:
    print(i)


#
# Using set() function
numbers = set([1, 2, 3, 4, 5])
print(numbers)  # Output: {1, 2, 3, 4, 5}


# Add items
# add()
set1 ={2,3,'python', 'data', 'science', 4,600,6,7} # len=9
set1.add(100)
set1

set1 ={2,3,'python', 'data', 'science', 4,600,6,7} # len=9
set1.add((10,20))
set1

# update()
s1 = {2,3,'python', 'data', 'science', 4,600,6,7} # len=9
s2 = {1,10,20,30,'a'}
s1.update(s2)
print(s1,len(s1))

# list elelment can be updated in set --correct/possible
s1 = {2,3,'python', 'data', 'science', 4,600,6,7} # len=9
l2 = [1,10,20,30,'a']
s1.update(l2)
print(s1,len(s1))


# Removing elements
# Use remove() to remove an element (raises an error if the element is not found).
# Use discard() to remove an element (no error if the element is not found).
# Use pop() to remove and return an arbitrary element.
# Use clear() to remove all elements from a set.

fruits.remove("banana")
print(fruits)  # Output: {'apple', 'cherry', 'orange', 'mango', 'grape'}

fruits.discard("grape")
print(fruits)  # Output: {'apple', 'cherry', 'orange', 'mango'}

popped_element = fruits.pop()
print(popped_element)  # Output: Random element from the set

# Clearing a set  ---Use clear() to remove all elements from a set.
fruits.clear()
print(fruits)  # Output: set()

# Copying a set  ---Use clear() to remove all elements from a set.
new_fruits = fruits.copy()
print(new_fruits)  # Output: set()


# union
s1 = {2,3,'python', 'data', 'science', 4,600,6,7} # len=9
s2 = {1,10,20,30,'a'}
s1.union(s2)

# Union
print(set1 | set2)  # Output: {1, 2, 3, 4, 5}


s1 = {2,3,40,10,20}
s2 = {10,20,1,'a'}
s1.update(s2)
print(s1)
print(s2)

# set and list ele union possible
s1 = {2,3,40,10,20}
l2 = [10,20,1,'a']
s1.union(l2)
# print(s1)
# print(l2)

#
# intersection
s1 = {2,3,40,10,20}
s2 = {10,20,1,'a'}
s3 = s1.intersection(s2)
print(s1)
print(s2)
print(s3)

# Intersection  ---Intersection: Finds common elements between two sets.
print(set1 & set2)  # Output: {3}



city1 = {'Pune' ,'Mumbai', "Nagpur",'Chennai'}
city2 = {'Pune','Kolkata', 'Bangalore','Mumbai'}
city3 = city1.intersection(city2)
print(city1)
print(city2)
print(city3)

# intersection_update
s1 = {2,3,40,10,20}
s2 = {10,20,1,'a'}
s1.intersection_update(s2)
print(s1)   # {10, 20}
print(s2)   # {1, 10, 20, 'a'}

city1 = {'Pune' ,'Mumbai', "Nagpur",'Chennai'}
city2 = {'Pune','Kolkata', 'Bangalore','Mumbai'}
city1.intersection_update(city2)
print(city1) # {'Pune', 'Mumbai'}
print(city2) # {'Bangalore', 'Kolkata', 'Pune', 'Mumbai'}

# difference()
s1 = {2,3,40,10,20}
s2 = {10,20,1,'a'}
s1.difference(s2)   # {2, 3, 40, 10, 20} will not change, need to store in another varibales
print(s1)
print(s2)

# Difference  --- Finds elements in one set but not in the other.
print(set1 - set2)  # Output: {1, 2}



s1 = {2,3,40,10,20}
s2 = {10,20,1,'a'}
s3 = s1.difference(s2)
print(s1)
print(s2)
print(s3)  ##{40, 2, 3}

# difference_update()
s1 = {2,3,40,10,20}
s2 = {10,20,1,'a'}
s2.difference_update(s1)
print(s1) #{2, 3, 40, 10, 20}
print(s2) #{1, 'a'}

# symmetric_difference
s1 = {2,3,40,10,20}
s2 = {10,20,1,'a'}
s2.symmetric_difference(s1)
print(s1)
print(s2)  # {1, 10, 20, 'a'}( will not show, need to store it in seperate variables)

#
s1 = {2,3,40,10,20}
s2 = {10,20,1,'a'}
s3 = s2.symmetric_difference(s1)
print(s1)
print(s2)
print(s3) # {1, 2, 3, 'a', 40}

# Symmetric Difference  ---Finds elements that are in either set but not in both.
print(set1 ^ set2)  # Output: {1, 2, 4, 5}

# symmetric_difference_update
s1 = {2,3,40,10,20}
s2 = {10,20,1,'a'}
s2.symmetric_difference_update(s1)
print(s1)
print(s2)  #{1, 2, 3, 40, 'a'}

#  issubset()
set1 = {2,3,4,5,6,10,20,'python','data'}
set2 = {2,3,4,'python'}
set2.issubset(set1)  # True

set1 = {2,3,4,5,6,10,20,'python','data'}
set2 = {2,3,4,'python'}
set1.issubset(set2)  # false

# issuperset()
set1 = {2,3,4,5,6,10,20,'python','data'}
set2 = {2,3,4,'python'}
set2.issuperset(set1)  ## False

set1 = {2,3,4,5,6,10,20,'python','data'}
set2 = {2,3,4,'python'}
set1.issuperset(set2)  # true


# isdisjoint()
True >> no common items in two sets
False >> if two sets have common items

s1 = {2,3,40,10,20}
s2 = {10,20,1,'a'}
s2.isdisjoint(s1) # False

s1 = {2,3,40,10,20}
s2 = {1,'a'}
s2.isdisjoint(s1) # True

# min()
s1 = {2,3,4,10,20}
min(s1)

# max()
s1 = {2,3,4,10,20}
max(s1)

# sum()
s1 = {2,3,4,10,20}
sum(s1)

# len()
s1 = {2,3,4,10,20}
len(s1)
