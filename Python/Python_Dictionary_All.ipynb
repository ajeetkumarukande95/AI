# %%
# Dict: Mutable, Insertion order is not preserved, Duplicates not allowed(only key)

# Python >= 3.6 >> Ordered Python <3.6 >> Unordered

# dict holds key and value pair comma seperated dict1= {'key':'value'} indexing and slicing are not applicable

# Duplicates not allowed: key >> Immutable Datatype : (int, float, str, tuple) >> Can not be duplicate value
# >> Any Datatype : (int, float, str, tuple, list , set, dict, array, dataframe) >> Can be Duplicate


d1 = {}
type(d1)

d1 = dict()
type(d1)

d1 = {'Name': 'Virat'}
len(d1)

d1 = {'Name': 'Virat', 'Age': 32}
print(d1,len(d1))

d1 = {'Name': 'Virat', 'Age': 32, 'Score':183}
print(d1,len(d1))


# Access Dictionary items
dict[keyname]

employee_data = {'Employee Name': 'Sagar',
                'Salary':50000,
                'Age':30,
                'Company':'Capgemini'}

print(employee_data, len(employee_data))

employee_data['Employee Name']
employee_data['Salary']

# get()
employee_data.get('Employee Name')

employee_data.get('Salary')

# dict Functions
1. keys()
2. values()
3. items()
# employee_data.keys()
# employee_data.values()
# employee_data.items()

# for loop on dictionary
employee_data = {'Employee Name': 'Sagar',
                'Salary':50000,
                'Age':30,
                'Company':'Capgemini'}

# access keys from dict
for key in employee_data: # Default we will get keys from dict
    print('Key is :',key)

for key in employee_data.keys():
    print('Key is :',key)


for key, val in employee_data.items():
    print(f'Key is {key} and Value is {val}')

# Check items in dictionary
employee_data = {'Employee Name': 'Sagar',
                'Salary':50000,
                'Age':30,
                'Company':'Capgemini'}
if 'Salary' in employee_data:
    print('Salary key is present')
else:
    print('Not present')

employee_data = {'Employee Name': 'Sagar',
                'Salary':50000,
                'Age':30,
                'Company':'Capgemini'}
if 'Experience' in employee_data:
    print('Salary key is present')
else:
    print('Not present')

# Change items of dictionary
employee_data = {'Employee Name': 'Sagar',
                'Salary':50000,
                'Age':30,
                'Company':'Capgemini'}
employee_data['Salary'] =60000
employee_data

employee_data = {'Employee Name': 'Sagar',
                'Salary':50000,
                'Age':30,
                'Company':'Capgemini'}
employee_data['Company'] ='TCS'
employee_data

# update()
employee_data = {'Employee Name': 'Sagar',
                'Salary':50000,
                'Age':30,
                'Company':'Capgemini'}

new_dict = {'Salary': 70000,
           'Age':31,
           'Company':'TCS'}

employee_data.update(new_dict)
employee_data

#
employee_data = {'Employee Name': 'Sagar',
                'Salary':50000,
                'Age':30,
                'Company':'Capgemini'}

employee_data.update({'Company':'TCS'})
employee_data

#
employee_data = {'Employee Name': 'Sagar',
                'Salary':50000,
                'Age':30,
                'Company':'Capgemini'}
new= {'Company':'TCS'}
employee_data.update(new)
employee_data

# Remove items from dict
1. pop
2. popitem
3. clear
4. del

employee_data={'Experience': '5 years',
               'Location': 'Pune',
               'Employee Name': 'Sagar',
               'Salary': 50000,
               'Age': 30,
               'Company': 'Capgemini'}
employee_data

# pop()
employee_data={'Experience': '5 years',
               'Location': 'Pune',
               'Employee Name': 'Sagar',
               'Salary': 50000,
               'Age': 30,
               'Company': 'Capgemini'}

employee_data.pop('Location')
print(employee_data, len(employee_data))

employee_data.pop('Location')
print(employee_data, len(employee_data))

employee_data.pop('Company')
print(employee_data, len(employee_data))

# popitem()
# Remove last / last inserted item

marksheet = {'Eng':83, 'Math':73, 'Sci':82}
marksheet.popitem()
marksheet

marksheet.popitem()
marksheet

# clear()
marksheet = {'Eng':83, 'Math':73, 'Sci':82}
marksheet.clear()
print(marksheet,len(marksheet))

# del
marksheet = {'Eng':83, 'Math':73, 'Sci':82}
del marksheet['Math']
marksheet

marksheet = {'Eng':83, 'Math':73, 'Sci':82}
del marksheet

# Nested Dictionary
class_1 = {'Virat':{'Eng':83,
                    'Math':73,
                    'Sci':82},

          'Rohit':{'Eng':81,
                   'Math':83,
                   'Sci':88},

          'Rahul':{'Eng':89,
                   'Math':81,
                   'Sci':80}}

print(class_1)
print('Length of dict is :',len(class_1))


class_1['Rahul']
type(class_1['Rahul'])
class_1['Rahul']['Eng']
class_1['Virat']['Sci']

data= {}
data['Name']='Sagar'
data['Loc']='Pune'
data

#
sub_names= ['Phy','Che','Math','Eng','Bio']
sub_marks= [93,94,91,95,90]
d1 = {}
for i in sub_names:
    for j in sub_marks:
        d1[i]=j

print(d1)

#
sub_names= ['Phy','Che','Math','Eng','Bio']
sub_marks= [93,94,91,95,90]
dict1 = {}

for i in range(len(sub_names)):
    dict1[sub_names[i]]=sub_marks[i]

print(dict1)


sub_names= ['Phy','Che','Math','Eng','Bio']
sub_marks= [93,94,91,95,90]
dict1 = {}
count=0
for key in sub_names:
    dict1[key]=sub_marks[count]
    count+=1
dict1

dict.fromkeys(seq,value)

sub_names= ['Phy','Che','Math','Eng','Bio']
sub_marks= [93,94,91,95,90]
dict.fromkeys(sub_names)  # {'Phy': None, 'Che': None, 'Math': None, 'Eng': None, 'Bio': None}

sub_names= ['Phy','Che','Math','Eng','Bio']
sub_marks= [93,94,91,95,90]
value=86
dict.fromkeys(sub_names,value)

sub_names= ['Phy','Che','Math','Eng','Bio']
sub_marks= [93,94,91,95,90]
value=86
dict.fromkeys(sub_names,sub_marks)


sub_names= ['Phy','Che','Math','Eng','Bio']
sub_marks= [93,94,91,95,90]
dict(zip(sub_names,sub_marks))

# square of 11 to 20 numbers
squares={}
for i in range(11,21):
    squares[i]=i**2
print(squares)


string='''Data science is an interdisciplinary field that uses scientific methods,
processes, algorithms and systems to extract knowledge and insights from noisy, structured
and unstructured data, and apply knowledge and actionable insights from data across a broad
range of application domains.'''

string = string.lower()
result={}
for word in string.split():
    result[word]= string.count(word)

print(result)

# ASCII Values for alphabets
lower_case={}
for i in range(97,123):
    lower_case.update({chr(i):i})

print(lower_case)

#
upper_case={}
for i in range(65,91):
    upper_case.update({chr(i):i})

print(upper_case)

# Sort Dictionary using Keys
sub_marks={'Phy': 93, 'Che': 94, 'Math': 91, 'Eng': 95, 'Bio': 90}
new_dict={}
sorted_keys=sorted(sub_marks.keys())

for key in sorted_keys:
    new_dict[key]=sub_marks[key]

new_dict

#
sub_marks={'Phy': 93, 'Che': 94, 'Math': 91, 'Eng': 95, 'Bio': 90}
sorted(sub_marks.keys())

#
sub_marks={'Phy': 93, 'Che': 94, 'Math': 91, 'Eng': 95, 'Bio': 90}
new_dict={}

for key in sorted(sub_marks.keys()):
    new_dict[key]=sub_marks[key]

new_dict


# Sort Dictionary using Values
sub_marks={'Phy': 93, 'Che': 94, 'Math': 91, 'Eng': 95, 'Bio': 90}
new_dict={}
for val in sorted(sub_marks.values()):
    for key in sub_marks:
        if sub_marks[key]==val:
            new_dict[key]=val

new_dict

# fromkeys
dict.fromkeys(seq,val) # default val is none

dict.fromkeys(['A','B','C','D']) #{'A': None, 'B': None, 'C': None, 'D': None}

dict.fromkeys(['A','B','C','D'],100)

dict.fromkeys(['A','B','C','D'],[100,200,300,400])
# {'A': [100, 200, 300, 400],
#  'B': [100, 200, 300, 400],
#  'C': [100, 200, 300, 400],
#  'D': [100, 200, 300, 400]}

alpha=['A','B','C','D']
num=[100,200,300,400]
dict(zip(alpha,num))

# {'A': 100, 'B': 200, 'C': 300, 'D': 400}

# setdefault()
dict.setdefault()
if key is present it returns corresponding value
if key is not present a key:value pair is added in dict

sub_marks={'Phy': 93, 'Che': 94, 'Math': 91, 'Eng': 95, 'Bio': 90}
sub_marks.setdefault('Math')  # 91

sub_marks={'Phy': 93, 'Che': 94, 'Math': 91, 'Eng': 95, 'Bio': 90}
sub_marks.setdefault('Che',92)  #94

sub_marks={'Phy': 93, 'Che': 94, 'Math': 91, 'Eng': 95, 'Bio': 90}
sub_marks.setdefault('Science')


sub_marks={'Phy': 93, 'Che': 94, 'Math': 91, 'Eng': 95, 'Bio': 90}
sub_marks.setdefault('Science',88)  # 88


# Dictionary comprehension ##--Similar to list comprehension, but for dictionaries.
squares = {x: x**2 for x in range(5)}
print(squares)  # Output: {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}



Dictionary Functions
get()
keys()
values()
items()
update()
fromkeys()
dict(zip())
pop()
popitem()
clear()
del
setdefault()
